# %% [markdown]
# <h1 style="color:#2F80ED;">👋 My name is Lamont</h1>
# <p style="font-size:18px;">
# I'm <b>excited</b> to learn about <span style="color:#27AE60;"><b>data analysis</b></span>
# and become an <i>expert</i>.
# </p>

# %%
numbers = [1,2,3,4]
largest = numbers[0]
for num in numbers:
    if num > largest:
        largest = num
print (largest)
